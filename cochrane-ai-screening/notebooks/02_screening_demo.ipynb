# %%
# Jupyter notebook for screening demonstration
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Systematic Review Screening Demo\n",
    "## Insulin Analogues Review"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Import libraries\n",
    "import sys\n",
    "sys.path.append('../src')\n",
    "\n",
    "from cochrane_screening import SystematicReviewScreener\n",
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import yaml\n",
    "\n",
    "# Load configuration\n",
    "with open('../config/insulin.yaml', 'r') as f:\n",
    "    config = yaml.safe_load(f)\n",
    "    \n",
    "print(f\"Review: {config['review_name']}\")\n",
    "print(f\"Inclusion terms: {len(config['inclusion']['population']['terms'])} population terms\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Initialize screener\n",
    "screener = SystematicReviewScreener('../config/insulin.yaml')\n",
    "\n",
    "# Run screening\n",
    "results = screener.screen('../data/insulin/input.ris', 'Insulin Demo')\n",
    "\n",
    "# Display results\n",
    "print(f\"\\nScreening Results:\")\n",
    "print(f\"  Total records: {len(screener.entries)}\")\n",
    "print(f\"  Included: {len(results['include'])}\")\n",
    "print(f\"  Maybe: {len(results['maybe'])}\")\n",
    "print(f\"  Excluded: {len(results['exclude'])}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Visualize results\n",
    "categories = ['Included', 'Maybe', 'Excluded']\n",
    "counts = [len(results['include']), len(results['maybe']), len(results['exclude'])]\n",
    "\n",
    "plt.figure(figsize=(8, 6))\n",
    "plt.bar(categories, counts, color=['green', 'orange', 'red'])\n",
    "plt.title('Screening Results Distribution')\n",
    "plt.ylabel('Number of Studies')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Save results\n",
    "output_dir = '../data/output/demo_run'\n",
    "summary = screener.save_results(output_dir, 'insulin_demo')\n",
    "print(f\"\\nResults saved to: {output_dir}\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
